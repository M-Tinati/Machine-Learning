# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#import data and check
data = pd.read_csv("../data/Insurance_Dataset.csv")
data.head()
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000

# %%
data.describe()
# Out:
#              Age       Premium
# count  77.000000     77.000000
# mean   25.857143  20214.285714
# std     4.914303   5855.962195
# min    18.000000  10000.000000
# 25%    22.000000  15000.000000
# 50%    26.000000  21000.000000
# 75%    31.000000  26500.000000
# max    33.000000  27000.000000

# %%
#train & test
Data = pd.DataFrame(data)
X = Data[["Age"]]
y = Data["Premium"]
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#model
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train , y_train)
y_predict = model.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error

print("Slope (coefficient): ", model.coef_[0])
print("Intercept: ", model.intercept_)

print("Predictions: ", y_predict)

print("R² score: ", r2_score(y_test, y_predict))
print("Mean Squared Error (MSE): ", mean_squared_error(y_test, y_predict))
# Out:
# Slope (coefficient):  1177.472228272708
# Intercept:  -10305.685035939892
# Predictions:  [26195.95404051 22663.5373557  22663.5373557  16776.17621433
#  20308.59289915 16776.17621433 28550.89849706 15598.70398606
#  26195.95404051 22663.5373557  26195.95404051 10888.81507297
#  26195.95404051 28550.89849706 20308.59289915 16776.17621433]
# R² score:  0.9555977185235687
# Mean Squared Error (MSE):  1071031.5942068894

# %%
def chart():
    plt.scatter(x_test, y_test, color='royalblue', label='Actual Values')
    plt.plot(x_test, y_predict, color='tomato', label='Model Predictions')
    plt.xlabel("Age")
    plt.ylabel("Premium")
    plt.title("Linear Regression: Age vs Premium")
    plt.legend()
    plt.grid(True)
    plt.show()
chart()
